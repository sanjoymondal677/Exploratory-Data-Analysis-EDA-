# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("/kaggle/input/the-big-three-anime-arcs/BigThree.csv")

# %%
data.head()
# Out:
#                  Arc  Start onChapter  TotalChapters  TotalPages Manga%  \
# 0   Romance Dawn Arc              1.0              7         178   0.9%
# 1    Orange Town Arc              8.0             14         273   1.4%
# 2  Syrup Village Arc             22.0             20         396   2.0%
# 3        Baratie Arc             42.0             27         514   2.6%
# 4    Arlong Park Arc             69.0             27         514   2.6%
#
#    Start onEpisode  TotalEpisodes  TotalMinutes(avg 24) Anime%   BigThree
# 0                1              3                    72   0.3%  One Piece
# 1                4              5                   120   0.5%  One Piece
# 2                9             10                   240   1.0%  One Piece
# 3               19             12                   288   1.2%  One Piece
# 4               31             15                   360   1.5%  One Piece

# %%
data.shape
# Out:
# (105, 10)

# %%
data['BigThree'].value_counts()
# Out:
# BigThree
# One Piece    51
# Naruto       37
# Bleach       17
# Name: count, dtype: int64

# %%
sns.countplot(x='BigThree',data=data)
plt.show()

# %%
sns.barplot(x='BigThree',y='Start onEpisode',data=data)
plt.show()
sns.barplot(x='BigThree',y='TotalEpisodes',data=data)
plt.show()
sns.barplot(x='BigThree',y='Start onChapter',data=data)
plt.show()
sns.barplot(x='BigThree',y='Start onChapter',data=data)
plt.show()
