# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("/kaggle/input/5g-coverage-worldwide/5g_coverage_worldwide.csv")

# %%
data.head()
# Out:
#         operator          city_name deployment_type                   status  \
# 0        Ooredoo  Abdullah al-Salem           5G NR  Commercial Availability
# 1          Optus           Canberra           5G NR  Commercial Availability
# 2          Optus             Sydney           5G NR  Commercial Availability
# 3  AT&T Mobility   Jacksonville, FL           5G NR  Commercial Availability
# 4  AT&T Mobility        Atlanta, GA           5G NR  Commercial Availability
#
#    latitude  longitude
# 0  29.35186   47.98369
# 1 -35.28200  149.12868
# 2 -33.86748  151.20698
# 3  30.33218  -81.65565
# 4  33.74900  -84.38798

# %%
import missingno as msno
msno.bar(data)
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='latitude',y='longitude',hue='deployment_type',data = data)
plt.show()

# %%
data['status'].count()
# Out:
# 145587

# %%
df_status = data.loc[data['status']!='Commercial Availability']

# %%
df_status.shape
# Out:
# (246, 6)

# %%
data.columns
# Out:
# Index(['operator', 'city_name', 'deployment_type', 'status', 'latitude',
#        'longitude'],
#       dtype='object')

# %%
data.shape
# Out:
# (145587, 6)

# %%
df = data.loc[(data['operator']=='Optus')]

# %%
df
# Out:
#       operator      city_name deployment_type                   status  \
# 1        Optus       Canberra           5G NR  Commercial Availability
# 2        Optus         Sydney           5G NR  Commercial Availability
# 1056     Optus         Dudley           5G NR  Commercial Availability
# 1057     Optus  Central Coast           5G NR  Commercial Availability
# 1058     Optus       Brisbane           5G NR  Commercial Availability
# ...        ...            ...             ...                      ...
# 22903    Optus   Coburg North           5G NR  Commercial Availability
# 22904    Optus      Joondalup           5G NR  Commercial Availability
# 22905    Optus    Mount Eliza           5G NR  Commercial Availability
# 24105    Optus       Bathurst           5G NR  Commercial Availability
# 97206    Optus         Hobart           5G NR  Commercial Availability
#
#         latitude   longitude
# 1     -35.282000  149.128680
# 2     -33.867480  151.206980
# ...

# %%
df.shape
# Out:
# (240, 6)

# %%
df_Ooredoo = data.loc[(data['operator']=='Ooredoo')]

# %%
df_Ooredoo.shape
# Out:
# (131, 6)

# %%
df_AT_T_Mobility = data.loc[(data['operator']=='AT&T Mobility')]

# %%
df_AT_T_Mobility.shape
# Out:
# (17448, 6)
