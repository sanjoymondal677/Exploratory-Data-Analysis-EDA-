# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("/content/sample_data/submissions_data_train.csv")

# %%
data.head()
# Out:
#    step_id   timestamp submission_status  user_id
# 0    31971  1434349275           correct  15853.0
# 1    31972  1434348300           correct  15853.0
# 2    31972  1478852149             wrong  15853.0
# 3    31972  1478852164           correct  15853.0
# 4    31976  1434348123             wrong  15853.0

# %%
data.isnull().sum()
# Out:
# step_id              0
# timestamp            0
# submission_status    0
# user_id              1
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106764 entries, 0 to 106763
# Data columns (total 4 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   step_id            106764 non-null  int64
#  1   timestamp          106764 non-null  int64
#  2   submission_status  106764 non-null  object
#  3   user_id            106763 non-null  float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 3.3+ MB

# %%
data['step_id'].unique()
# Out:
# array([ 31971,  31972,  31976,  31977,  31978,  31979,  31981,  31983,
#         31986,  31988,  31991,  32031,  32075,  32089,  32173,  32174,
#         32175,  32190,  32198,  32202,  32206,  32219,  32244,  32763,
#         32795,  32796,  32809,  32810,  32812,  32929,  33025,  33079,
#         33332,  33334,  33350,  33351,  33362,  33367,  33413,  33415,
#         33418,  33420,  33439,  33480,  33481,  33482,  33487,  33488,
#         33534,  33536,  33538,  33539,  33540,  33669,  33673,  33674,
#         33675,  33676,  33677,  33681,  33684,  33685,  33686,  33713,
#         33731,  33732,  33734,  33874,  33890,  33983,  33984,  33992,
#         33994,  33998,  34041, 120745])

# %%
ax=sns.countplot(x='submission_status',data=data,color='#9EDDFF')
for label in ax.containers:
    ax.bar_label(label)
plt.show()

# %%
event_data_train = pd.read_csv("/content/sample_data/event_data_train.csv")

# %%
event_data_train.head()
# Out:
#    step_id     timestamp      action  user_id
# 0    32815  1.434341e+09      viewed  17632.0
# 1    32815  1.434341e+09      passed  17632.0
# 2    32815  1.434341e+09  discovered  17632.0
# 3    32811  1.434341e+09  discovered  17632.0
# 4    32811  1.434341e+09      viewed  17632.0

# %%
event_data_train.isnull().sum()
# Out:
# step_id      0
# timestamp    1
# action       1
# user_id      1
# dtype: int64

# %%
ax=sns.countplot(x='action',data=event_data_train)
for label in ax.containers:
    ax.bar_label(label)
plt.show()
